# %%
#transporting necessary package

import pandas as pd
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("Raga Pilu.csv")

# %%
print(df.head())
# Out:
#    Song Name  P(S)=X1  P(r )=X2  P(R)=X3  P(g)=X4  P(G)=X5  P(M)=X6  P(m)=X7  \
# 0  Raag Pilu    0.125         0      0.1   0.1625    0.125      0.2        0
#
#    P(P)=X8  P(d)=X9  P(D)=X10  P(n)=X11  P(N)=X12
# 0   0.1375        0     0.025         0     0.125

# %%
x=pd.plotting.andrews_curves(df,'Song Name', color="red")
